# %%
from glob import glob
import shutil
import os
import dicom2nifti
import nibabel as nib
import numpy as np

# %%
input_niffti_file_path = 'E:/Liver_Segementation_prg/nifti_files/labels/*'
count = 0
for p in glob(input_niffti_file_path):
    niffti_file = nib.load(p)
    fdata = niffti_file.get_fdata()
    np_unique = np.unique(fdata)
    if len(np_unique) == 1:
        print(np_unique)
        print(p)
        count+=1

print(count)
# Out:
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_0.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_1.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_2.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_3.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_4.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_5.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_6.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_7.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_8.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_100_9.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_0.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_1.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_2.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_3.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_4.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_5.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_6.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_7.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_8.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_101_9.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_0.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_1.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_2.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_3.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_4.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_5.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_6.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_7.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_8.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_102_9.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_0.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_1.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_2.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_3.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_4.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_5.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_6.nii
# [0.]
# E:/Liver_Segementation_prg/nifti_files/labels\liver_103_7.nii
# 38
